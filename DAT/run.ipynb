# %%
# %cd D:\SR\baseline\DAT
# %pwd
# Out:
# d:\SR\baseline\DAT
# c:\Users\kychai\AppData\Local\anaconda3\envs\geoAI\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# 'd:\\SR\\baseline\\DAT'

# %%
# !python train_moveoutside.py -opt options/Train/train_DAT_x3.yml
# Out:
# Disable distributed.
# Path already exists. Rename it to d:\SR\baseline\DAT\experiments\train_DAT_x3_archived_20240524_094021
# Path already exists. Rename it to d:\SR\baseline\DAT\tb_logger\train_DAT_x3_archived_20240524_094021
# file updated
# start epoch loop, total epochs15
# read in training data finished
# start feeding data into model
# start optimizaing parameters
# start feeding data into model
# start optimizaing parameters
# start feeding data into model
# start optimizaing parameters
# read in training data finished
# start feeding data into model
# start optimizaing parameters
# start feeding data into model
# start optimizaing parameters
# start feeding data into model
# start optimizaing parameters
# read in training data finished
# start feeding data into model
# start optimizaing parameters
# start feeding data into model
# start optimizaing parameters
# start feeding data into model
# start optimizaing parameters
# read in training data finished
# ...

# %%
# !python train_moveoutside.py -opt options/Train/train_DAT_x3.yml
# Out:
# Disable distributed.
# Path already exists. Rename it to d:\SR\baseline\DAT\experiments\train_DAT_x3_archived_20240524_095651
# Path already exists. Rename it to d:\SR\baseline\DAT\tb_logger\train_DAT_x3_archived_20240524_095651
# file updated
# start epoch loop, total epochs15
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# read in training data finished
# 2024-05-24 09:56:51,080 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
# ...

# %%
#!python -m torch.distributed.launch --nproc_per_node=1 --master_port=4321 train_moveoutside.py -opt options/Train/train_DAT_x3.yml --launcher pytorch
# Out:
# W0524 12:17:24.441000 22672 torch\distributed\elastic\multiprocessing\redirects.py:27] NOTE: Redirects are currently not supported in Windows or MacOs.
# c:\Users\kychai\AppData\Local\anaconda3\envs\geoAI\Lib\site-packages\torch\distributed\launch.py:183: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# [W socket.cpp:697] [c10d] The client socket has failed to connect to [view-localhost]:4321 (system error: 10049 - The requested address is not valid in its context.).
# usage: train_moveoutside.py [-h] -opt OPT [--launcher {none,pytorch,slurm}]
#                             [--auto_resume] [--debug]
# ...
