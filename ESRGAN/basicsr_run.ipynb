# %%
# %cd D:\SR\baseline\BasicSR
# %pwd
# Out:
# d:\SR\baseline\BasicSR
# c:\Users\kychai\AppData\Local\anaconda3\envs\geoAI\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# 'd:\\SR\\baseline\\BasicSR'

# %%
# !python train_moveoutside.py -opt options/train/ESRGAN/train_ESRGAN_x4.yml
# Out:
# Disable distributed.
# 2024-05-27 11:25:32,072 INFO:
#                 ____                _       _____  ____
#                / __ ) ____ _ _____ (_)_____/ ___/ / __ \
#               / __  |/ __ `// ___// // ___/\__ \ / /_/ /
#              / /_/ // /_/ /(__  )/ // /__ ___/ // _, _/
#             /_____/ \__,_//____//_/ \___//____//_/ |_|
#      ______                   __   __                 __      __
#     / ____/____   ____   ____/ /  / /   __  __ _____ / /__   / /
#    / / __ / __ \ / __ \ / __  /  / /   / / / // ___// //_/  / /
#   / /_/ // /_/ // /_/ // /_/ /  / /___/ /_/ // /__ / /<    /_/
#   \____/ \____/ \____/ \____/  /_____/\____/ \___//_/|_|  (_)
#
# Version Information:
# 	BasicSR: 1.3.5
# 	PyTorch: 2.3.0
# 	TorchVision: 0.18.0
# 2024-05-27 11:25:32,073 INFO:
#   name: 052_ESRGAN_x4
#   model_type: ESRGANModel
#   scale: 4
#   num_gpu: 1
#   manual_seed: 0
#   datasets:[
#     train:[
#       name: Noisy_Test
#       type: PairedImageDataset
# ...
